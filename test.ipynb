# %%
import pyvisa

rm = pyvisa.ResourceManager()
device = rm.open_resource("USB0::0x0957::0x2607::MY59001073::0::INSTR")

device.write("*IDN?")
print(device.read())
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pyvisa
#       2
#       3 rm = pyvisa.ResourceManager()
# ----> 4 device = rm.open_resource("USB0::0x0957::0x2607::MY59001073::0::INSTR")
#       5
#       6 device.write("*IDN?")
#       7 print(device.read())
#
# File D:\Aniket\PyTunes\.venv\Lib\site-packages\pyvisa\highlevel.py:3302, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3296     if not present:
#    3297         raise ValueError(
#    3298             "%r is not a valid attribute for type %s"
#    3299             % (key, res.__class__.__name__)
#    3300         )
# -> 3302 res.open(access_mode, open_timeout)
#    3304 for key, value in kwargs.items():
#    3305     setattr(res, key, value)
#
# ...

# %%
NOTE_NAMES = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
A4_INDEX = NOTE_NAMES.index("A") + (4 * 12)


def note_frequency(note_index):
    return round(440.0 * (2 ** ((note_index - A4_INDEX) / 12)), 2)


note_dict = {}

for octave in range(0, 9):
    for semitone, note_name in enumerate(NOTE_NAMES):
        note = f"{note_name}{octave}"
        note_index = semitone + (octave * 12)
        note_dict[note] = note_frequency(note_index)
